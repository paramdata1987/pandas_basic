# %% [markdown]
# # Pandas I/O Tools

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\DELL\Desktop\empl.xlsx")
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df['Salary'].max()
# Out:
# 67666.0

# %%
df=pd.read_csv('employ.csv',index_col=['SNo'])
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df=pd.read_csv('employ.csv',dtype={'Salary':np.float64})
print(df.dtypes)
df
# Out:
# SNo          int64
# Name        object
# Age        float64
# City        object
# Country     object
# Salary     float64
# dtype: object
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# ...

# %%
df['Salary'].plot()

# %%
df1=pd.DataFrame(data=df)
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1.loc[:,'Salary']
# Out:
# 0     20000.0
# 1      3900.0
# 2      8000.0
# 3     66672.0
# 4         NaN
# 5     30007.0
# 6      8300.0
# 7     54666.0
# 8     67666.0
# 9      8888.0
# 10    66672.0
# 11    34344.0
# 12    30007.0
# 13     8300.0
# 14    54666.0
# 15    67666.0
# 16     8888.0
# 17        NaN
# 18    34432.0
# 19    34534.0
# 20    33451.0
# 21        NaN
# Name: Salary, dtype: float64

# %%
df1.loc[:,{'Name','Salary','City'}]
# Out:
#      Salary       City    Name
# 0   20000.0    Toronto     Tom
# 1    3900.0    Edmonto     Lee
# 2    8000.0    Toronto    Dave
# 3   66672.0   HongKong    Anik
# 4       NaN        NaN   kamal
# 5   30007.0   HongKong    Geet
# 6    8300.0    BayArea  Steven
# 7   54666.0  Hyderabad     Ram
# 8   67666.0    newyork    hari
# 9    8888.0    newyork    yami
# 10  66672.0   HongKong    Anik
# 11  34344.0        NaN   kamal
# 12  30007.0   HongKong    Geet
# 13   8300.0        NaN  Steven
# 14  54666.0  Hyderabad     Ram
# 15  67666.0    newyork    hari
# 16   8888.0    newyork    yami
# 17      NaN    Edmonto     Lee
# 18  34432.0      Congo  Andrew
# 19  34534.0     Angola   soham
# 20  33451.0    Finland    Grig
# 21      NaN     London   Kiara

# %%
df1.iloc[:,1:4]
# Out:
#       Name   Age       City
# 0      Tom  28.0    Toronto
# 1      Lee  31.0    Edmonto
# 2     Dave  34.0    Toronto
# 3     Anik  26.0   HongKong
# 4    kamal  30.0        NaN
# 5     Geet   NaN   HongKong
# 6   Steven  43.0    BayArea
# 7      Ram  38.0  Hyderabad
# 8     hari  50.0    newyork
# 9     yami   NaN    newyork
# 10    Anik  26.0   HongKong
# 11   kamal  30.0        NaN
# 12    Geet  22.0   HongKong
# 13  Steven  43.0        NaN
# 14     Ram  38.0  Hyderabad
# 15    hari   NaN    newyork
# 16    yami  27.0    newyork
# 17     Lee  31.0    Edmonto
# 18  Andrew  34.0      Congo
# 19   soham  32.0     Angola
# 20    Grig  26.0    Finland
# 21   Kiara  27.0     London

# %%
df1.count()
# Out:
# SNo        22
# Name       22
# Age        19
# City       19
# Country    22
# Salary     19
# dtype: int64

# %%
df1['Name'].count()
# Out:
# 22

# %%
df1['Name'].unique()
# Out:
# array(['Tom', 'Lee', 'Dave', 'Anik', 'kamal', 'Geet', 'Steven', 'Ram',
#        'hari', 'yami', 'Andrew', 'soham', 'Grig', 'Kiara'], dtype=object)

# %%
df1['Name'].nunique()
# Out:
# 14

# %%
df1['City'].unique()
# Out:
# array(['Toronto', 'Edmonto', 'HongKong', nan, 'BayArea', 'Hyderabad',
#        'newyork', 'Congo', 'Angola', 'Finland', 'London'], dtype=object)

# %%
df1['City'].nunique()
# Out:
# 10

# %%
df1['City'].describe()
# Out:
# count           19
# unique          10
# top       HongKong
# freq             4
# Name: City, dtype: object

# %%
df1.describe()
# Out:
#              SNo        Age        Salary
# count  22.000000  19.000000     19.000000
# mean   12.090909  32.421053  33739.947368
# std     6.927578   7.174924  23151.188084
# min     1.000000  22.000000   3900.000000
# 25%     6.250000  27.000000   8888.000000
# 50%    12.500000  31.000000  33451.000000
# 75%    17.750000  36.000000  54666.000000
# max    23.000000  50.000000  67666.000000

# %%
df1['Salary'].plot.box()

# %%
df1['Age'].plot.box()

# %%
df1.plot.bar(stacked=True)
